# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating
# 0      159    19     10000  Free      0       Everyone
# 1      967    14    500000  Free      0       Everyone
# 2    87510     8   5000000  Free      0       Everyone
# 3   215644    25  50000000  Free      0           Teen
# 4      967     2    100000  Free      0       Everyone

# %% [markdown]
# ## 1) Converting dataframe to array

# %%
data = df.values

# %%
data.shape
# Out:
# (10829, 9)

# %%
data[0]
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN',
#        4.1, 159, 19, 10000, 'Free', 0, 'Everyone'], dtype=object)

# %%
data[1]
# Out:
# array(['Coloring book moana', 'ART_AND_DESIGN', 3.9, 967, 14, 500000,
#        'Free', 0, 'Everyone'], dtype=object)

# %%
data[2]
# Out:
# array(['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#        'ART_AND_DESIGN', 4.7, 87510, 8, 5000000, 'Free', 0, 'Everyone'],
#       dtype=object)

# %%
data[3]
# Out:
# array(['Sketch - Draw & Paint', 'ART_AND_DESIGN', 4.5, 215644, 25,
#        50000000, 'Free', 0, 'Teen'], dtype=object)

# %% [markdown]
# ## 2) Slicing Array

# %%
data[0:5, 0:3]
# Out:
# array([['Photo Editor & Candy Camera & Grid & ScrapBook',
#         'ART_AND_DESIGN', 4.1],
#        ['Coloring book moana', 'ART_AND_DESIGN', 3.9],
#        ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#         'ART_AND_DESIGN', 4.7],
#        ['Sketch - Draw & Paint', 'ART_AND_DESIGN', 4.5],
#        ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', 4.3]],
#       dtype=object)

# %% [markdown]
# ## 3) Analyse - Print all apps name which comes under ART_AND_DESIGN

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating
# 0      159    19     10000  Free      0       Everyone
# 1      967    14    500000  Free      0       Everyone
# 2    87510     8   5000000  Free      0       Everyone
# 3   215644    25  50000000  Free      0           Teen
# 4      967     2    100000  Free      0       Everyone

# %%
for i in data:
    
    if (i[1] == 'ART_AND_DESIGN'):
        print(i[0])
# Out:
# Photo Editor & Candy Camera & Grid & ScrapBook
# Coloring book moana
# U Launcher Lite – FREE Live Cool Themes, Hide Apps
# Sketch - Draw & Paint
# Pixel Draw - Number Art Coloring Book
# Paper flowers instructions
# Smoke Effect Photo Maker - Smoke Editor
# Infinite Painter
# Garden Coloring Book
# Kids Paint Free - Drawing Fun
# Text on Photo - Fonteee
# Name Art Photo Editor - Focus n Filters
# Tattoo Name On My Photo Editor
# Mandala Coloring Book
# 3D Color Pixel by Number - Sandbox Art Coloring
# Photo Designer - Write your name with shapes
# 350 Diy Room Decor Ideas
# FlipaClip - Cartoon animation
# ibis Paint X
# Logo Maker - Small Business
# Boys Photo Editor - Six Pack & Men's Suit
# Superheroes Wallpapers | 4K Backgrounds
# Mcqueen Coloring pages
# HD Mickey Minnie Wallpapers
# Harley Quinn wallpapers HD
# Colorfit - Drawing & Coloring
# Animated Photo Editor
# Pencil Sketch Drawing
# Easy Realistic Drawing Tutorial
# Pink Silver Bow Keyboard Theme
# Art Drawing Ideas
# ...

# %% [markdown]
# ## 4) Print all the details of the application that comes under DATING category

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating
# 0      159    19     10000  Free      0       Everyone
# 1      967    14    500000  Free      0       Everyone
# 2    87510     8   5000000  Free      0       Everyone
# 3   215644    25  50000000  Free      0           Teen
# 4      967     2    100000  Free      0       Everyone

# %%
print('-'*50)

for i in data:
    if(i[1] == 'DATING'):
        
        print("Name           : ", i[0])
        print("Rating         : ", i[2])
        print("Reviews        : ", i[3])
        print("Size           : ", i[4])
        print("Installs       : ", i[5])
        print("Type           : ", i[6])
        print("Price          : ", i[7])
        print("Content Rating : ", i[8])
        
        print('-'*50)
# Out:
# --------------------------------------------------
# Name           :  Moco+ - Chat, Meet People
# Rating         :  4.2
# Reviews        :  1545
# Size           :  10
# Installs       :  10000
# Type           :  Paid
# Price          :  299
# Content Rating :  Mature 17+
# --------------------------------------------------
# Name           :  Calculator
# Rating         :  2.6
# Reviews        :  57
# Size           :  6
# Installs       :  1000
# Type           :  Paid
# Price          :  524
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  Truth or Dare Pro
# Rating         :  4.4
# Reviews        :  0
# Size           :  20
# Installs       :  50
# Type           :  Paid
# Price          :  111
# Content Rating :  Teen
# --------------------------------------------------
# Name           :  Private Dating, Hide App- Blue for PrivacyHider
# Rating         :  4.4
# Reviews        :  0
# Size           :  1
# ...

# %% [markdown]
# ## 5) Search application based on the name

# %%
title = 'Dating'

n = 1

for i in data:
    if(title.lower() in i[0].lower()):
        print(str(n) +'.', i[0])
        
        n += 1
# Out:
# 1. Private Dating, Hide App- Blue for PrivacyHider
# 2. AMBW Dating App: Asian Men Black Women Interracial
# 3. Zoosk Dating App: Meet Singles
# 4. OkCupid Dating
# 5. Match™ Dating - Meet Singles
# 6. Hily: Dating, Chat, Match, Meet & Hook up
# 7. Hinge: Dating & Relationships
# 8. Casual Dating & Adult Singles - Joyride
# 9. BBW Dating & Plus Size Chat
# 10. CMB Free Dating App
# 11. eharmony - Online Dating App
# 12. Free Dating App & Flirt Chat - Match with Singles
# 13. Chispa, the Dating App for Latino, Latina Singles
# 14. Clover Dating App
# 15. Mingle2 - Free Online Dating & Singles Chat Rooms
# 16. Free Dating App & Flirt Chat - Cheers
# 17. Free Dating Hook Up Messenger
# 18. Find Real Love — YouLove Premium Dating
# 19. Cougar Dating Life : Date Older Women Sugar Mummy
# 20. Free Dating & Flirt Chat - Choice of Love
# 21. BeWild Free Dating & Chat App
# 22. FastMeet: Chat, Dating, Love
# 23. Free Dating App - YoCutie - Flirt, Chat & Meet
# ...

# %% [markdown]
# ## 6) Print all the application names with rating 5

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating
# 0      159    19     10000  Free      0       Everyone
# 1      967    14    500000  Free      0       Everyone
# 2    87510     8   5000000  Free      0       Everyone
# 3   215644    25  50000000  Free      0           Teen
# 4      967     2    100000  Free      0       Everyone

# %%
c = 1

for i in data:
    if (i[2] == 5):
        print(str(c) + '.' + i[0])
        c += 1
# Out:
# 1.Hojiboy Tojiboyev Life Hacks
# 2.American Girls Mobile Numbers
# 3.Awake Dating
# 4.Spine- The dating app
# 5.Girls Live Talk - Free Text and Video Chat
# 6.Online Girls Chat Group
# 7.Speeding Joyride & Car Meet App
# 8.SUMMER SONIC app
# 9.Prosperity
# 10.Mindvalley U Tallinn 2018
# 11.Eternal life
# 12.Super Hearing Secret Voices Recorder PRO
# 13.FHR 5-Tier 2.0
# 14.Sway Medical
# 15.Labs on Demand
# 16.Dermatology Atlas (Colored & Illustrative)
# 17.Tablet Reminder
# 18.Galaxies of Hope
# 19.KBA-EZ Health Guide
# 20.FoothillsVet
# 21.PrimeDelivery
# 22.You're an Anime
# 23.Anatomy & Physiology Vocabulary Exam Review App
# 24.NCLEX Multi-topic Nursing Exam Review-Quiz & notes
# 25.Basics of Orthopaedics
# 26.Clinic Doctor EHr
# 27.Sway Medical
# 28.420 BZ Budeze Delivery
# 29.BP Journal - Blood Pressure Diary
# 30.Zen Leaf
# 31.ADS-B Driver
# 32.P-Home for KLWP
# 33.Android P Style Icon Pack
# 34.R Programing Offline Tutorial
# 35.Easy Hotspot Ad Free
# ...

# %%
print('-'*50)

for i in data:
    if (i[2] == 5):        
        print("Name           : ", i[0])
        print("Rating         : ", i[2])
        print("Reviews        : ", i[3])
        print("Size           : ", i[4])
        print("Installs       : ", i[5])
        print("Type           : ", i[6])
        print("Price          : ", i[7])
        print("Content Rating : ", i[8])
        print('-'*50)
# Out:
# --------------------------------------------------
# Name           :  Hojiboy Tojiboyev Life Hacks
# Rating         :  5.0
# Reviews        :  15
# Size           :  37
# Installs       :  1000
# Type           :  Free
# Price          :  0
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  American Girls Mobile Numbers
# Rating         :  5.0
# Reviews        :  5
# Size           :  4
# Installs       :  1000
# Type           :  Free
# Price          :  0
# Content Rating :  Mature 17+
# --------------------------------------------------
# Name           :  Awake Dating
# Rating         :  5.0
# Reviews        :  2
# Size           :  70
# Installs       :  100
# Type           :  Free
# Price          :  0
# Content Rating :  Mature 17+
# --------------------------------------------------
# Name           :  Spine- The dating app
# Rating         :  5.0
# Reviews        :  5
# Size           :  9
# Installs       :  500
# ...

# %% [markdown]
# ## 7) List all the paid apps in ART_AND_DESIGN category

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating
# 0      159    19     10000  Free      0       Everyone
# 1      967    14    500000  Free      0       Everyone
# 2    87510     8   5000000  Free      0       Everyone
# 3   215644    25  50000000  Free      0           Teen
# 4      967     2    100000  Free      0       Everyone

# %%
print('-'*50)

for i in data:

    if(i[6] == 'Paid' and i[1] == 'ART_AND_DESIGN'):

        print("Name           : ", i[0])
        print("Price          : ", i[7])
        print('-'*50)
# Out:
# --------------------------------------------------
# Name           :  X Launcher Pro: PhoneX Theme, OS11 Control Center
# Price          :  149
# --------------------------------------------------
# Name           :  X Launcher Pro - IOS Style Theme & Control Center
# Price          :  149
# --------------------------------------------------
# Name           :  X Launcher Prime: With OS Style Theme & No Ads
# Price          :  149
# --------------------------------------------------

# %% [markdown]
# ## 8) List all the paid GAMES

# %%
for i in data:
    if(i[1] == 'GAME' and i[6] == 'Paid'):

        print("Name           : ", i[0])
        print("Price          : ", i[7])
        print('-'*50)
# Out:
# Name           :  The Game of Life
# Price          :  224
# --------------------------------------------------
# Name           :  Clue
# Price          :  149
# --------------------------------------------------
# Name           :  The Room: Old Sins
# Price          :  374
# --------------------------------------------------
# Name           :  The Escapists
# Price          :  374
# --------------------------------------------------
# Name           :  Farming Simulator 18
# Price          :  374
# --------------------------------------------------
# Name           :  RollerCoaster Tycoon® Classic
# Price          :  449
# --------------------------------------------------
# Name           :  Call of Duty:Black Ops Zombies
# Price          :  524
# --------------------------------------------------
# Name           :  Star Wars ™: DIRTY
# Price          :  749
# --------------------------------------------------
# Name           :  Monument Valley 2
# Price          :  374
# ...

# %% [markdown]
# ## 9) List all paid GAMES with rating 5

# %%
print('-'*50)

for i in data:
    
    if(i[1] == 'GAME' and i[6] == 'Paid' and i[2] == 5):

        print("Name           : ", i[0])
        print("Rating         : ", i[2])
        print("Reviews        : ", i[3])
        print("Size           : ", i[4])
        print("Installs       : ", i[5])
        print("Type           : ", i[6])
        print("Price          : ", i[7])
        print("Content Rating : ", i[8])
        print('-'*50)
# Out:
# --------------------------------------------------
# Name           :  Ra Ga Ba
# Rating         :  5.0
# Reviews        :  2
# Size           :  20
# Installs       :  1
# Type           :  Paid
# Price          :  111
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  211:CK
# Rating         :  5.0
# Reviews        :  8
# Size           :  38
# Installs       :  10
# Type           :  Paid
# Price          :  74
# Content Rating :  Teen
# --------------------------------------------------
# Name           :  Santa's Monster Shootout DX
# Rating         :  5.0
# Reviews        :  4
# Size           :  33
# Installs       :  50
# Type           :  Paid
# Price          :  149
# Content Rating :  Teen
# --------------------------------------------------
# Name           :  Mu.F.O.
# Rating         :  5.0
# Reviews        :  2
# Size           :  16
# Installs       :  1
# Type           :  Paid
# Price          :  74
# ...

# %% [markdown]
# ## 10) List all paid apps with 10000+ reviews, 100000+ Installs for everyone

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating
# 0      159    19     10000  Free      0       Everyone
# 1      967    14    500000  Free      0       Everyone
# 2    87510     8   5000000  Free      0       Everyone
# 3   215644    25  50000000  Free      0           Teen
# 4      967     2    100000  Free      0       Everyone

# %%
print('-'*50)

for i in data:
    if(i[6] == 'Paid' and i[3]>10000  and i[5]>100000 and i[8] == 'Everyone'):
        
        print("Name           : ", i[0])
        print("Rating         : ", i[2])
        print("Reviews        : ", i[3])
        print("Size           : ", i[4])
        print("Installs       : ", i[5])
        print("Type           : ", i[6])
        print("Price          : ", i[7])
        print("Content Rating : ", i[8])
        print('-'*50)
# Out:
# --------------------------------------------------
# Name           :  Toca Life: City
# Rating         :  4.7
# Reviews        :  31085
# Size           :  24
# Installs       :  500000
# Type           :  Paid
# Price          :  299
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  Toca Life: City
# Rating         :  4.7
# Reviews        :  31100
# Size           :  24
# Installs       :  500000
# Type           :  Paid
# Price          :  299
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  Facetune - For Free
# Rating         :  4.4
# Reviews        :  49553
# Size           :  48
# Installs       :  1000000
# Type           :  Paid
# Price          :  449
# Content Rating :  Everyone
# --------------------------------------------------
# Name           :  Facetune - For Free
# Rating         :  4.4
# Reviews        :  49553
# Size           :  48
# Installs       :  1000000
# ...

# %% [markdown]
# ## 11) Print the application Details of ROBLOX

# %%
for i in data:
    if(i[0] == 'ROBLOX'):
        
        print("Name           : ", i[0])
        print("Rating         : ", i[2])
        print("Reviews        : ", i[3])
        print("Size           : ", i[4])
        print("Installs       : ", i[5])
        print("Type           : ", i[6])
        print("Price          : ", i[7])
        print("Content Rating : ", i[8])
        print('-'*50)
# Out:
# Name           :  ROBLOX
# Rating         :  4.5
# Reviews        :  4447388
# Size           :  67
# Installs       :  100000000
# Type           :  Free
# Price          :  0
# Content Rating :  Everyone 10+
# --------------------------------------------------
# Name           :  ROBLOX
# Rating         :  4.5
# Reviews        :  4447346
# Size           :  67
# Installs       :  100000000
# Type           :  Free
# Price          :  0
# Content Rating :  Everyone 10+
# --------------------------------------------------
# Name           :  ROBLOX
# Rating         :  4.5
# Reviews        :  4448791
# Size           :  67
# Installs       :  100000000
# Type           :  Free
# Price          :  0
# Content Rating :  Everyone 10+
# --------------------------------------------------
# Name           :  ROBLOX
# Rating         :  4.5
# Reviews        :  4449882
# Size           :  67
# Installs       :  100000000
# Type           :  Free
# Price          :  0
# ...
